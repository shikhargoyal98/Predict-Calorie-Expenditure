# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
train = pd.read_csv('/Users/shikhargoyal/Documents/Kaggle/playground-series-s5e5/train.csv')
test = pd.read_csv('/Users/shikhargoyal/Documents/Kaggle/playground-series-s5e5/test.csv')

# %%
train.head()
# Out:
#    id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    male   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1  female   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2  female   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    male   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4  female   38   166.0    61.0      25.0       102.0       40.6     146.0

# %%
train.isnull().sum()/len(train)*100
# Out:
# id            0.0
# Sex           0.0
# Age           0.0
# Height        0.0
# Weight        0.0
# Duration      0.0
# Heart_Rate    0.0
# Body_Temp     0.0
# Calories      0.0
# dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestRegressor
from scipy.stats import randint

# ------------------------
# Step 1: Separate features and target
# ------------------------
X = train.drop(columns=["Calories"])  # Adjust if needed
y = train["Calories"]

# ------------------------
# Step 2: Identify column types
# ------------------------
num_cols = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
cat_cols = X.select_dtypes(include=["object", "category"]).columns.tolist()

# ------------------------
# Step 3: Preprocessing pipeline
# ------------------------
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

# ------------------------
# Step 4: Full pipeline
# ------------------------
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=42))
])

# ------------------------
# Step 5: Hyperparameter distributions
# ------------------------
param_dist = {
    'regressor__n_estimators': randint(100, 300),
    'regressor__max_depth': randint(5, 20),
    'regressor__min_samples_split': randint(2, 10),
    'regressor__min_samples_leaf': randint(1, 5)
}

# ------------------------
# Step 6: RandomizedSearchCV
# ------------------------
random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_dist,
    n_iter=20,
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=2,
    random_state=42
)

# ------------------------
# Step 7: Fit model
# ------------------------
random_search.fit(X, y)

# ------------------------
# Step 8: Results
# ------------------------
print("✅ Best Params:", random_search.best_params_)
print("🏆 Best RMSE (CV):", -random_search.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=114; total time= 5.0min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=120; total time=40.9min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=114; total time= 5.0min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=120; total time=40.9min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=114; total time= 5.1min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=2, regressor__min_samples_split=4, regressor__n_estimators=174; total time=54.8min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=199; total time=201.5min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=257; total time=263.3min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=287; total time=257.3min
# [CV] END regressor__max_depth=5, regressor__min_samples_leaf=3, regressor__min_samples_split=4, regressor__n_estimators=269; total time=82.2min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=4, regressor__min_samples_split=9, regressor__n_estimators=114; total time=21.7min
# [CV] END regressor__max_depth=7, regressor__min_samples_leaf=4, regressor__min_samples_split=8, regressor__n_estimators=163; total time= 5.1min
# [CV] END regressor__max_depth=7, regressor__min_samples_leaf=4, regressor__min_samples_split=8, regressor__n_estimators=163; total time= 5.1min
# [CV] END regressor__max_depth=13, regressor__min_samples_leaf=3, regressor__min_samples_split=6, regressor__n_estimators=150; total time=54.9min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=1, regressor__min_samples_split=2, regressor__n_estimators=266; total time=120.3min
# [CV] END regressor__max_depth=14, regressor__min_samples_leaf=1, regressor__min_samples_split=3, regressor__n_estimators=183; total time=321.8min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=1, regressor__min_samples_split=9, regressor__n_estimators=274; total time=493.5min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=114; total time= 5.0min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=2, regressor__min_samples_split=4, regressor__n_estimators=174; total time=54.9min
# [CV] END regressor__max_depth=12, regressor__min_samples_leaf=4, regressor__min_samples_split=4, regressor__n_estimators=249; total time=218.9min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=257; total time=303.4min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=157; total time=109.1min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=157; total time=91.5min
# [CV] END regressor__max_depth=5, regressor__min_samples_leaf=3, regressor__min_samples_split=4, regressor__n_estimators=269; total time=82.2min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=8, regressor__n_estimators=289; total time=63.0min
# [CV] END regressor__max_depth=13, regressor__min_samples_leaf=3, regressor__min_samples_split=6, regressor__n_estimators=150; total time=25.8min
# [CV] END regressor__max_depth=6, regressor__min_samples_leaf=4, regressor__min_samples_split=2, regressor__n_estimators=159; total time=31.4min
# [CV] END regressor__max_depth=6, regressor__min_samples_leaf=4, regressor__min_samples_split=2, regressor__n_estimators=159; total time=85.8min
# [CV] END regressor__max_depth=14, regressor__min_samples_leaf=1, regressor__min_samples_split=3, regressor__n_estimators=183; total time=291.3min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=3, regressor__min_samples_split=5, regressor__n_estimators=298; total time=643.1min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=114; total time= 5.0min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=2, regressor__min_samples_split=4, regressor__n_estimators=174; total time=54.8min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=199; total time=201.4min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=257; total time=245.9min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=287; total time=274.8min
# [CV] END regressor__max_depth=5, regressor__min_samples_leaf=3, regressor__min_samples_split=4, regressor__n_estimators=269; total time=82.2min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=4, regressor__min_samples_split=9, regressor__n_estimators=114; total time=21.7min
# [CV] END regressor__max_depth=7, regressor__min_samples_leaf=4, regressor__min_samples_split=8, regressor__n_estimators=163; total time= 5.1min
# [CV] END regressor__max_depth=7, regressor__min_samples_leaf=4, regressor__min_samples_split=8, regressor__n_estimators=163; total time= 5.1min
# [CV] END regressor__max_depth=13, regressor__min_samples_leaf=3, regressor__min_samples_split=6, regressor__n_estimators=150; total time=54.9min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=1, regressor__min_samples_split=2, regressor__n_estimators=266; total time=120.3min
# [CV] END regressor__max_depth=14, regressor__min_samples_leaf=1, regressor__min_samples_split=3, regressor__n_estimators=183; total time=306.7min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=3, regressor__min_samples_split=5, regressor__n_estimators=298; total time=639.0min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=120; total time= 6.7min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=2, regressor__min_samples_split=4, regressor__n_estimators=174; total time=54.7min
# [CV] END regressor__max_depth=12, regressor__min_samples_leaf=4, regressor__min_samples_split=4, regressor__n_estimators=249; total time=260.4min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=257; total time=272.5min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=157; total time=115.1min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=188; total time=110.9min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=4, regressor__min_samples_split=9, regressor__n_estimators=114; total time=63.4min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=8, regressor__n_estimators=289; total time=62.2min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=1, regressor__min_samples_split=2, regressor__n_estimators=266; total time=108.5min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=3, regressor__n_estimators=108; total time=204.2min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=3, regressor__min_samples_split=5, regressor__n_estimators=298; total time=532.4min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=199; total time=199.7min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=257; total time=217.0min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=287; total time=313.1min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=188; total time=88.9min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=4, regressor__min_samples_split=9, regressor__n_estimators=114; total time=21.8min
# [CV] END regressor__max_depth=7, regressor__min_samples_leaf=4, regressor__min_samples_split=8, regressor__n_estimators=163; total time= 5.1min
# [CV] END regressor__max_depth=13, regressor__min_samples_leaf=3, regressor__min_samples_split=6, regressor__n_estimators=150; total time=36.8min
# [CV] END regressor__max_depth=13, regressor__min_samples_leaf=3, regressor__min_samples_split=6, regressor__n_estimators=150; total time=26.0min
# [CV] END regressor__max_depth=6, regressor__min_samples_leaf=4, regressor__min_samples_split=2, regressor__n_estimators=159; total time=31.3min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=3, regressor__n_estimators=108; total time=208.3min
# [CV] END regressor__max_depth=14, regressor__min_samples_leaf=1, regressor__min_samples_split=3, regressor__n_estimators=183; total time=261.6min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=1, regressor__min_samples_split=9, regressor__n_estimators=274; total time=675.7min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=120; total time= 6.7min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=2, regressor__min_samples_split=4, regressor__n_estimators=174; total time=54.7min
# [CV] END regressor__max_depth=12, regressor__min_samples_leaf=4, regressor__min_samples_split=4, regressor__n_estimators=249; total time=260.5min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=287; total time=307.9min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=157; total time=136.1min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=188; total time=89.5min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=4, regressor__min_samples_split=9, regressor__n_estimators=114; total time=30.5min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=8, regressor__n_estimators=289; total time=65.9min
# [CV] END regressor__max_depth=6, regressor__min_samples_leaf=4, regressor__min_samples_split=2, regressor__n_estimators=159; total time=31.6min
# [CV] END regressor__max_depth=6, regressor__min_samples_leaf=4, regressor__min_samples_split=2, regressor__n_estimators=159; total time=37.9min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=3, regressor__n_estimators=108; total time=203.6min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=3, regressor__min_samples_split=5, regressor__n_estimators=298; total time=520.2min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=1, regressor__min_samples_split=9, regressor__n_estimators=274; total time=409.2min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=120; total time= 6.7min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=199; total time=124.1min
# [CV] END regressor__max_depth=12, regressor__min_samples_leaf=4, regressor__min_samples_split=4, regressor__n_estimators=249; total time=269.0min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=2, regressor__min_samples_split=9, regressor__n_estimators=287; total time=308.8min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=188; total time=93.7min
# [CV] END regressor__max_depth=5, regressor__min_samples_leaf=3, regressor__min_samples_split=4, regressor__n_estimators=269; total time=80.5min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=8, regressor__n_estimators=289; total time=62.2min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=1, regressor__min_samples_split=2, regressor__n_estimators=266; total time=59.9min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=3, regressor__n_estimators=108; total time=219.7min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=3, regressor__min_samples_split=5, regressor__n_estimators=298; total time=503.2min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=1, regressor__min_samples_split=9, regressor__n_estimators=274; total time=425.5min
# [CV] END regressor__max_depth=15, regressor__min_samples_leaf=4, regressor__min_samples_split=6, regressor__n_estimators=199; total time=199.7min
# [CV] END regressor__max_depth=12, regressor__min_samples_leaf=4, regressor__min_samples_split=4, regressor__n_estimators=249; total time=347.2min
# [CV] END regressor__max_depth=9, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=157; total time=98.6min
# [CV] END regressor__max_depth=10, regressor__min_samples_leaf=1, regressor__min_samples_split=5, regressor__n_estimators=188; total time=93.2min
# [CV] END regressor__max_depth=5, regressor__min_samples_leaf=3, regressor__min_samples_split=4, regressor__n_estimators=269; total time=82.1min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=8, regressor__n_estimators=289; total time=62.9min
# [CV] END regressor__max_depth=11, regressor__min_samples_leaf=1, regressor__min_samples_split=2, regressor__n_estimators=266; total time=57.2min
# [CV] END regressor__max_depth=18, regressor__min_samples_leaf=2, regressor__min_samples_split=3, regressor__n_estimators=108; total time=208.1min
# [CV] END regressor__max_depth=14, regressor__min_samples_leaf=1, regressor__min_samples_split=3, regressor__n_estimators=183; total time=306.5min
# [CV] END regressor__max_depth=16, regressor__min_samples_leaf=1, regressor__min_samples_split=9, regressor__n_estimators=274; total time=630.5min
# ✅ Best Params: {'regressor__max_depth': 16, 'regressor__min_samples_leaf': 4, 'regressor__min_samples_split': 9, 'regressor__n_estimators': 114}
# 🏆 Best RMSE (CV): 3.75230221939621

# %%
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import GradientBoostingRegressor
from scipy.stats import uniform, randint

# ------------------------
# Step 1: Separate features and target
# ------------------------
X = train.drop(columns=["Calories"])  # Adjust column name if needed
y = train["Calories"]

# ------------------------
# Step 2: Identify column types
# ------------------------
num_cols = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
cat_cols = X.select_dtypes(include=["object", "category"]).columns.tolist()

# ------------------------
# Step 3: Preprocessing pipeline
# ------------------------
preprocessor = ColumnTransformer(transformers=[
    ('num', StandardScaler(), num_cols),
    ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols)
])

# ------------------------
# Step 4: Full pipeline
# ------------------------
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', GradientBoostingRegressor(random_state=42))
])

# ------------------------
# Step 5: Hyperparameter distributions for RandomizedSearchCV
# ------------------------
param_dist = {
    'regressor__n_estimators': randint(100, 300),
    'regressor__learning_rate': uniform(0.01, 0.2),
    'regressor__max_depth': randint(3, 8),
    'regressor__subsample': uniform(0.7, 0.3)
}

# ------------------------
# Step 6: RandomizedSearchCV
# ------------------------
random_search = RandomizedSearchCV(
    pipeline,
    param_distributions=param_dist,
    n_iter=20,  # You can reduce to 10 for even faster tuning
    cv=5,
    scoring='neg_root_mean_squared_error',
    n_jobs=-1,
    verbose=2,
    random_state=42
)

# ------------------------
# Step 7: Fit model
# ------------------------
random_search.fit(X, y)

# ------------------------
# Step 8: Results
# ------------------------
print("✅ Best Params:", random_search.best_params_)
print("🏆 Best RMSE (CV):", -random_search.best_score_)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] END regressor__learning_rate=0.0849080237694725, regressor__max_depth=7, regressor__n_estimators=114, regressor__subsample=0.9195981825434215; total time= 6.2min
# [CV] END regressor__learning_rate=0.15439975445336496, regressor__max_depth=4, regressor__n_estimators=291, regressor__subsample=0.9976634677873653; total time=10.0min
# [CV] END regressor__learning_rate=0.13349630192554332, regressor__max_depth=4, regressor__n_estimators=121, regressor__subsample=0.7021198915659151; total time= 3.0min
# [CV] END regressor__learning_rate=0.014612485008283152, regressor__max_depth=5, regressor__n_estimators=158, regressor__subsample=0.8199582915145766; total time= 5.5min
# [CV] END regressor__learning_rate=0.16703519227860275, regressor__max_depth=5, regressor__n_estimators=207, regressor__subsample=0.8542703315240834; total time= 7.6min
# [CV] END regressor__learning_rate=0.1284829137724085, regressor__max_depth=5, regressor__n_estimators=150, regressor__subsample=0.9040922615763338; total time=42.7min
# [CV] END regressor__learning_rate=0.12265764356910785, regressor__max_depth=4, regressor__n_estimators=108, regressor__subsample=0.7047898756660642; total time= 3.7min
# [CV] END regressor__learning_rate=0.056178765124429805, regressor__max_depth=6, regressor__n_estimators=210, regressor__subsample=0.9049790556476374; total time=10.7min
# [CV] END regressor__learning_rate=0.1425044568707964, regressor__max_depth=4, regressor__n_estimators=233, regressor__subsample=0.7623824988604566; total time= 7.1min
# [CV] END regressor__learning_rate=0.1235400655639983, regressor__max_depth=7, regressor__n_estimators=290, regressor__subsample=0.9526854323784995; total time=17.8min
# [CV] END regressor__learning_rate=0.0877354579378964, regressor__max_depth=4, regressor__n_estimators=210, regressor__subsample=0.9486212527455787; total time= 6.7min
# [CV] END regressor__learning_rate=0.08135066533871785, regressor__max_depth=6, regressor__n_estimators=287, regressor__subsample=0.8628088249474745; total time=13.0min
# [CV] END regressor__learning_rate=0.0849080237694725, regressor__max_depth=7, regressor__n_estimators=114, regressor__subsample=0.9195981825434215; total time= 6.2min
# [CV] END regressor__learning_rate=0.07674172222780437, regressor__max_depth=5, regressor__n_estimators=249, regressor__subsample=0.71692347370813; total time= 7.7min
# [CV] END regressor__learning_rate=0.13349630192554332, regressor__max_depth=4, regressor__n_estimators=121, regressor__subsample=0.7021198915659151; total time= 3.2min
# [CV] END regressor__learning_rate=0.014612485008283152, regressor__max_depth=5, regressor__n_estimators=158, regressor__subsample=0.8199582915145766; total time= 5.5min
# [CV] END regressor__learning_rate=0.019333132642723086, regressor__max_depth=6, regressor__n_estimators=114, regressor__subsample=0.8368209952651107; total time= 5.0min
# [CV] END regressor__learning_rate=0.1284829137724085, regressor__max_depth=5, regressor__n_estimators=150, regressor__subsample=0.9040922615763338; total time= 5.7min
# [CV] END regressor__learning_rate=0.1000998503939086, regressor__max_depth=4, regressor__n_estimators=231, regressor__subsample=0.9826605267054558; total time=45.7min
# [CV] END regressor__learning_rate=0.056178765124429805, regressor__max_depth=6, regressor__n_estimators=210, regressor__subsample=0.9049790556476374; total time=10.8min
# [CV] END regressor__learning_rate=0.1235400655639983, regressor__max_depth=7, regressor__n_estimators=290, regressor__subsample=0.9526854323784995; total time=18.7min
# [CV] END regressor__learning_rate=0.1554543991712842, regressor__max_depth=6, regressor__n_estimators=289, regressor__subsample=0.7975990992289792; total time=11.6min
# [CV] END regressor__learning_rate=0.0877354579378964, regressor__max_depth=4, regressor__n_estimators=210, regressor__subsample=0.9486212527455787; total time= 7.0min
# [CV] END regressor__learning_rate=0.03818484499495253, regressor__max_depth=7, regressor__n_estimators=164, regressor__subsample=0.7046909220223582; total time= 7.2min
# [CV] END regressor__learning_rate=0.12973169683940733, regressor__max_depth=4, regressor__n_estimators=174, regressor__subsample=0.8377746675897602; total time= 5.1min
# [CV] END regressor__learning_rate=0.07674172222780437, regressor__max_depth=5, regressor__n_estimators=249, regressor__subsample=0.71692347370813; total time= 7.7min
# [CV] END regressor__learning_rate=0.15439975445336496, regressor__max_depth=4, regressor__n_estimators=291, regressor__subsample=0.9976634677873653; total time= 9.9min
# [CV] END regressor__learning_rate=0.019333132642723086, regressor__max_depth=6, regressor__n_estimators=114, regressor__subsample=0.8368209952651107; total time= 5.0min
# [CV] END regressor__learning_rate=0.1284829137724085, regressor__max_depth=5, regressor__n_estimators=150, regressor__subsample=0.9040922615763338; total time= 5.7min
# [CV] END regressor__learning_rate=0.1000998503939086, regressor__max_depth=4, regressor__n_estimators=231, regressor__subsample=0.9826605267054558; total time=45.8min
# [CV] END regressor__learning_rate=0.13199933155652419, regressor__max_depth=5, regressor__n_estimators=180, regressor__subsample=0.777633994480005; total time= 6.4min
# [CV] END regressor__learning_rate=0.13199933155652419, regressor__max_depth=5, regressor__n_estimators=180, regressor__subsample=0.777633994480005; total time= 7.1min
# [CV] END regressor__learning_rate=0.1235400655639983, regressor__max_depth=7, regressor__n_estimators=290, regressor__subsample=0.9526854323784995; total time=18.5min
# [CV] END regressor__learning_rate=0.1554543991712842, regressor__max_depth=6, regressor__n_estimators=289, regressor__subsample=0.7975990992289792; total time=11.6min
# [CV] END regressor__learning_rate=0.08135066533871785, regressor__max_depth=6, regressor__n_estimators=287, regressor__subsample=0.8628088249474745; total time=12.8min
# [CV] END regressor__learning_rate=0.0849080237694725, regressor__max_depth=7, regressor__n_estimators=114, regressor__subsample=0.9195981825434215; total time= 6.2min
# [CV] END regressor__learning_rate=0.07674172222780437, regressor__max_depth=5, regressor__n_estimators=249, regressor__subsample=0.71692347370813; total time= 7.7min
# [CV] END regressor__learning_rate=0.13349630192554332, regressor__max_depth=4, regressor__n_estimators=121, regressor__subsample=0.7021198915659151; total time= 3.2min
# [CV] END regressor__learning_rate=0.13349630192554332, regressor__max_depth=4, regressor__n_estimators=121, regressor__subsample=0.7021198915659151; total time= 2.9min
# [CV] END regressor__learning_rate=0.014612485008283152, regressor__max_depth=5, regressor__n_estimators=158, regressor__subsample=0.8199582915145766; total time= 5.5min
# [CV] END regressor__learning_rate=0.16703519227860275, regressor__max_depth=5, regressor__n_estimators=207, regressor__subsample=0.8542703315240834; total time= 7.5min
# [CV] END regressor__learning_rate=0.1000998503939086, regressor__max_depth=4, regressor__n_estimators=231, regressor__subsample=0.9826605267054558; total time=45.7min
# [CV] END regressor__learning_rate=0.056178765124429805, regressor__max_depth=6, regressor__n_estimators=210, regressor__subsample=0.9049790556476374; total time=10.8min
# [CV] END regressor__learning_rate=0.1425044568707964, regressor__max_depth=4, regressor__n_estimators=233, regressor__subsample=0.7623824988604566; total time= 7.0min
# [CV] END regressor__learning_rate=0.09995082667395314, regressor__max_depth=4, regressor__n_estimators=289, regressor__subsample=0.9779976597381381; total time=11.4min
# [CV] END regressor__learning_rate=0.09995082667395314, regressor__max_depth=4, regressor__n_estimators=289, regressor__subsample=0.9779976597381381; total time= 9.5min
# [CV] END regressor__learning_rate=0.0877354579378964, regressor__max_depth=4, regressor__n_estimators=210, regressor__subsample=0.9486212527455787; total time= 6.8min
# [CV] END regressor__learning_rate=0.08135066533871785, regressor__max_depth=6, regressor__n_estimators=287, regressor__subsample=0.8628088249474745; total time=12.4min
# [CV] END regressor__learning_rate=0.12973169683940733, regressor__max_depth=4, regressor__n_estimators=174, regressor__subsample=0.8377746675897602; total time= 5.0min
# [CV] END regressor__learning_rate=0.12973169683940733, regressor__max_depth=4, regressor__n_estimators=174, regressor__subsample=0.8377746675897602; total time= 4.9min
# [CV] END regressor__learning_rate=0.15439975445336496, regressor__max_depth=4, regressor__n_estimators=291, regressor__subsample=0.9976634677873653; total time=10.0min
# [CV] END regressor__learning_rate=0.014612485008283152, regressor__max_depth=5, regressor__n_estimators=158, regressor__subsample=0.8199582915145766; total time= 5.5min
# [CV] END regressor__learning_rate=0.16703519227860275, regressor__max_depth=5, regressor__n_estimators=207, regressor__subsample=0.8542703315240834; total time= 7.6min
# [CV] END regressor__learning_rate=0.1000998503939086, regressor__max_depth=4, regressor__n_estimators=231, regressor__subsample=0.9826605267054558; total time=45.7min
# [CV] END regressor__learning_rate=0.056178765124429805, regressor__max_depth=6, regressor__n_estimators=210, regressor__subsample=0.9049790556476374; total time=10.8min
# [CV] END regressor__learning_rate=0.1425044568707964, regressor__max_depth=4, regressor__n_estimators=233, regressor__subsample=0.7623824988604566; total time= 7.0min
# [CV] END regressor__learning_rate=0.09995082667395314, regressor__max_depth=4, regressor__n_estimators=289, regressor__subsample=0.9779976597381381; total time=11.4min
# [CV] END regressor__learning_rate=0.09995082667395314, regressor__max_depth=4, regressor__n_estimators=289, regressor__subsample=0.9779976597381381; total time= 9.5min
# [CV] END regressor__learning_rate=0.0877354579378964, regressor__max_depth=4, regressor__n_estimators=210, regressor__subsample=0.9486212527455787; total time= 6.8min
# [CV] END regressor__learning_rate=0.08135066533871785, regressor__max_depth=6, regressor__n_estimators=287, regressor__subsample=0.8628088249474745; total time=12.4min
# [CV] END regressor__learning_rate=0.0849080237694725, regressor__max_depth=7, regressor__n_estimators=114, regressor__subsample=0.9195981825434215; total time= 6.2min
# [CV] END regressor__learning_rate=0.07674172222780437, regressor__max_depth=5, regressor__n_estimators=249, regressor__subsample=0.71692347370813; total time= 7.7min
# [CV] END regressor__learning_rate=0.13349630192554332, regressor__max_depth=4, regressor__n_estimators=121, regressor__subsample=0.7021198915659151; total time= 3.2min
# [CV] END regressor__learning_rate=0.014612485008283152, regressor__max_depth=5, regressor__n_estimators=158, regressor__subsample=0.8199582915145766; total time= 5.5min
# [CV] END regressor__learning_rate=0.019333132642723086, regressor__max_depth=6, regressor__n_estimators=114, regressor__subsample=0.8368209952651107; total time= 5.0min
# [CV] END regressor__learning_rate=0.16703519227860275, regressor__max_depth=5, regressor__n_estimators=207, regressor__subsample=0.8542703315240834; total time=25.3min
# [CV] END regressor__learning_rate=0.12265764356910785, regressor__max_depth=4, regressor__n_estimators=108, regressor__subsample=0.7047898756660642; total time=21.8min
# [CV] END regressor__learning_rate=0.12265764356910785, regressor__max_depth=4, regressor__n_estimators=108, regressor__subsample=0.7047898756660642; total time= 3.7min
# [CV] END regressor__learning_rate=0.12265764356910785, regressor__max_depth=4, regressor__n_estimators=108, regressor__subsample=0.7047898756660642; total time= 2.7min
# [CV] END regressor__learning_rate=0.13199933155652419, regressor__max_depth=5, regressor__n_estimators=180, regressor__subsample=0.777633994480005; total time= 6.9min
# [CV] END regressor__learning_rate=0.1425044568707964, regressor__max_depth=4, regressor__n_estimators=233, regressor__subsample=0.7623824988604566; total time= 7.0min
# [CV] END regressor__learning_rate=0.1235400655639983, regressor__max_depth=7, regressor__n_estimators=290, regressor__subsample=0.9526854323784995; total time=18.1min
# [CV] END regressor__learning_rate=0.1554543991712842, regressor__max_depth=6, regressor__n_estimators=289, regressor__subsample=0.7975990992289792; total time=11.6min
# [CV] END regressor__learning_rate=0.03818484499495253, regressor__max_depth=7, regressor__n_estimators=164, regressor__subsample=0.7046909220223582; total time= 7.2min
# [CV] END regressor__learning_rate=0.03818484499495253, regressor__max_depth=7, regressor__n_estimators=164, regressor__subsample=0.7046909220223582; total time= 5.6min
# [CV] END regressor__learning_rate=0.0849080237694725, regressor__max_depth=7, regressor__n_estimators=114, regressor__subsample=0.9195981825434215; total time= 6.2min
# [CV] END regressor__learning_rate=0.07674172222780437, regressor__max_depth=5, regressor__n_estimators=249, regressor__subsample=0.71692347370813; total time= 7.7min
# [CV] END regressor__learning_rate=0.15439975445336496, regressor__max_depth=4, regressor__n_estimators=291, regressor__subsample=0.9976634677873653; total time= 9.9min
# [CV] END regressor__learning_rate=0.019333132642723086, regressor__max_depth=6, regressor__n_estimators=114, regressor__subsample=0.8368209952651107; total time= 5.1min
# [CV] END regressor__learning_rate=0.1284829137724085, regressor__max_depth=5, regressor__n_estimators=150, regressor__subsample=0.9040922615763338; total time=23.5min
# [CV] END regressor__learning_rate=0.1000998503939086, regressor__max_depth=4, regressor__n_estimators=231, regressor__subsample=0.9826605267054558; total time=27.9min
# [CV] END regressor__learning_rate=0.13199933155652419, regressor__max_depth=5, regressor__n_estimators=180, regressor__subsample=0.777633994480005; total time= 6.5min
# [CV] END regressor__learning_rate=0.13199933155652419, regressor__max_depth=5, regressor__n_estimators=180, regressor__subsample=0.777633994480005; total time= 7.1min
# [CV] END regressor__learning_rate=0.1235400655639983, regressor__max_depth=7, regressor__n_estimators=290, regressor__subsample=0.9526854323784995; total time=18.3min
# [CV] END regressor__learning_rate=0.1554543991712842, regressor__max_depth=6, regressor__n_estimators=289, regressor__subsample=0.7975990992289792; total time=11.6min
# [CV] END regressor__learning_rate=0.08135066533871785, regressor__max_depth=6, regressor__n_estimators=287, regressor__subsample=0.8628088249474745; total time=12.6min
# ✅ Best Params: {'regressor__learning_rate': 0.03818484499495253, 'regressor__max_depth': 7, 'regressor__n_estimators': 164, 'regressor__subsample': 0.7046909220223582}
# 🏆 Best RMSE (CV): 3.680317603959767

# %%
test.head()
# Out:
#        id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  750000    male   45   177.0    81.0       7.0        87.0       39.8
# 1  750001    male   26   200.0    97.0      20.0       101.0       40.5
# 2  750002  female   29   188.0    85.0      16.0       102.0       40.4
# 3  750003  female   39   172.0    73.0      20.0       107.0       40.6
# 4  750004  female   30   173.0    67.0      16.0        94.0       40.5

# %%
# ------------------------
# Step 9: Predict on test data
# ------------------------

# Assuming your test set is loaded as:
# test = pd.read_csv("test.csv")

# Save test IDs before dropping
test_ids = test["id"]

# Drop unnecessary columns if needed
#X_test = test.drop(columns=["id"])

# Apply the same transformations using the fitted pipeline
predictions = random_search.best_estimator_.predict(test)

# ------------------------
# Step 10: Save predictions to CSV
# ------------------------
output_df = pd.DataFrame({
    "id": test_ids,
    "Calories": predictions
})

# Save to CSV
output_df.to_csv("/Users/shikhargoyal/Documents/Kaggle/playground-series-s5e5/submissionrr.csv", index=False)
print("✅ Predictions saved to submission.csv")
# Out:
# ✅ Predictions saved to submission.csv
